# %%
import gensim
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api

from rutermextract import TermExtractor

import nltk
nltk.download("stopwords")
#--------#

from nltk.corpus import stopwords
from pymystem3 import Mystem
from string import punctuation

import wget
import zipfile

from os import listdir
from os.path import isfile, join
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/pihanya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#model_name = 'glove-wiki-gigaword-100'
#model_name = 'word2vec-ruscorpora-300'
model_url = 'http://vectors.nlpl.eu/repository/20/182.zip'

word2vec_postfixes = ['_PROPN', '_NOUN', '_ADJ', '_VERB']
russian_stopwords = stopwords.words("russian")

# %%
mystem = Mystem() 
term_extractor = TermExtractor()

# %%
#model = api.load(model_name)

# загрузка word2vec модели из сети
if not 'model.bin' in listdir('.'):
    m = wget.download(model_url)

model_file = model_url.split('/')[-1]
with zipfile.ZipFile(model_file, 'r') as archive:
    stream = archive.open('model.bin')
    model = gensim.models.KeyedVectors.load_word2vec_format(stream, binary=True)

# %%
questions = []
answers = []

dir_name = './feb'

files = [f for f in listdir(dir_name) if isfile(join(dir_name, f))]
for file_name in files:
    file = open(join(dir_name, file_name), 'r')
    lines = file.readlines()
    for i in range(len(lines)):
        lines[i] = lines[i][:-1]
    
    question = lines[0]
    answer = ' '.join(lines[1:])
                
    questions.append(question)
    answers.append(answer)

# %%
#### хорошие словосочетания - все слова есть в словаре word2vec
# плохие словосочетания - есть хотя бы одно слово не из словаря word2vec
# хорошее слово - слово из словаря word2vec
# плохое слово - слово не из словаря word2vec


# find_metrics( report_text, [idx, question] ): [ (idx, bp_metric, gp_metric, bw_metric, gw_metric, s_metric) ]
# 0. приводим все слова из факов к нормальной форме

#    extract_keys( text ): (bad_phrases, good_phrases, bad_word, good_words)
# 1. получаем из обращения важные слова и словосочетания с нормализированными словами
# 2. словосочетания закидываем в функцию классификации результата, на выходе получаются:
#    хорошие словосочетания, плохие словосочетания, хорошие слова, плохие слова

# 3. проходимся по всей базе вопросов-ответов и пробуем найти совпадение с текстом обращения:
#        по плохим словосочетаниям (метрика bp_metric)
#        по хорошим словосочетаниям (метрика gp_metric)
#        по плохим словам (метрика bw_metric)
#        по хорошим словам (метрика gw_metric)
#    в качестве значения метрики можно использовать количество символов или слов !(потом изучим)!
#    находя в факовом вопросе словосочетание из обращение, вытираем словосочетание
#      и все его слова из соответствующей категории
#    находя в факовом вопросе слово, вытираем его

# 4. для оставшихся плохих посчитаем метрику ненайденных плохих слов и словосочетаний !(длина или кол-во слов)!
#    Метрики: nfb_metric

#    find_synonymous( good_words ): 
# 5. если остались хорошие слова и/или словосочетания, занимаемся поиском метрики синонимичности
#    для этого все хорошие словосочетания дробим на слова и формируем один большой список хороших слов
#    и для каждого слова находим N самых близких слов и кладем в общий пул синонимов 


# 5.1 в вопросах факов найдем количество слов из пула синонимов. это количество будет метрикой синонимичности:
#     syn_metric

# %%
# является ли данный текст фразой или словом
def is_phrase(text):
    return ' ' in text

# сопоставить слову словарное слово из word2vec
# map_word2vec_word( word ): (is_success, word2vec_word or source_word)
def map_word2vec_word(word):
    temp_tokens = [word + x for x in word2vec_postfixes]
    for temp_token in temp_tokens:
        try:
            model.word_vec(temp_token)
        except Exception:
            pass
        else:
            return (True, temp_token)
        
    return (False, word)

# %%
# выделение важных слов и словосочетаний
# find_tokens( text ): array of phrases and words
def find_tokens(text):
    tokens = []
    for term in term_extractor(text):
        term_extractor(text)
        tokens.append(term.normalized)
        
    return tokens

# нормализация текста
# normalize_words( text ): normalized_text
def normalize_words(text):
    tokens = mystem.lemmatize(text.lower())
    tokens = [token for token in tokens if token not in russian_stopwords\
              and token != " " \
              and token.strip() not in punctuation]
    return ' '.join(tokens)

# %%
# найти хорошие/плохие словосочетания и слова
# extract_keys( text ): (bad_phrases, good_phrases, bad_words, good_words) - all sets
def extract_keys(text):
    bad_phrases, good_phrases = [], []
    bad_words, good_words = [], []
    
    tokens = [normalize_words(token) for token in find_tokens(text)]
    
    word_tokens = [token for token in tokens if not is_phrase(token)]
    phrase_tokens = [token for token in tokens if is_phrase(token)]
    for phrase in phrase_tokens:
        for word in phrase.split(' '):
            word_tokens.append(word)
    
    # распределение фраз по категориям
    for phrase in phrase_tokens:
        words = phrase.split(' ')
        for word in words:
            success, _ = map_word2vec_word(word)
            if not success:
                bad_phrases.append(phrase)
                break
        else:
            good_phrases.append(phrase)
    
    # распределение слов по категориям
    for word in word_tokens:
        success, _ = map_word2vec_word(word)
        if not success:
            bad_words.append(word)
        else:
            good_words.append(word)
    
    return (set(bad_phrases), set(good_phrases), set(bad_words), set(good_words))

# %%
# значение метрики - длина фразы (в словах)
def metric_value(token):
    return len(token.split(' '))   

# поиск значений различных метрик
# syn_coeff - минимальное значение похожести слов в word2vec для поиска синонимов
# find_metric( report_text, question, syn_coeff ): ( metrics, hits )
# metrics - массив из метрик. порядок метрик такой же как в шапке метода
# hits - тапл из четырех массивов: найденные совпадения плохих словосочетаний,
#        хороших словосочетаний, плохих слов, хороших слов
def find_metric( report_text, question, syn_coeff=0.5 ):
    question = normalize_words(question)
    
    bp_metric = 0.0 # плохие словосочетания
    gp_metric = 0.0 # хорошие словосочетания
    bw_metric = 0.0 # плохие слова
    gw_metric = 0.0 # хорошие слова
    syn_metric = 0.0 # метрика по синонимам
    nfb_metric = 0.0 # ненайденные плохие слова и словосочетания
    nfg_metric = 0.0 # ненайденные хорошие слова и словосочетания
    
    bad_phrases, good_phrases, bad_words, good_words = extract_keys(report_text)
    
    # не найденные слова
    nf_bad_words, nf_good_words = set(), set()
    
    # найденные совпадения
    bad_phrases_hits, good_phrases_hits = set(), set()
    bad_words_hits, good_words_hits = set(), set()
    
    # поиск значения метрики плохих словосочетаний
    for phrase in bad_phrases:
        metric = metric_value(phrase)
        if phrase in question:
            bad_phrases_hits.add(phrase)
            bp_metric += metric
            
            # больше не ищем слова из словосочетания
            for word in phrase.split(' '):
                if word in bad_words:
                    bad_words.remove(word)
                if word in good_words:
                    good_words.remove(word)
        else:
            # если не нашли, тогда помещаем все плохие слова из плохих словосочетаний в пул ненайденных плохих слов 
            words = phrase.split(' ')
            for word in words:
                is_good, _ = map_word2vec_word(word)
                if not is_good:
                    nf_bad_words.add(word)
            
    # поиск значения метрики хороших словосочетаний
    for phrase in good_phrases:
        if phrase in question:
            good_phrases_hits.add(phrase)
            bp_metric += metric_value(phrase)
            
            # больше не ищем слова из словосочетания
            for word in phrase.split(' '):
                if word in good_words:
                    good_words.remove(word)
        else:
            # если не нашли, тогда помещаем все хорошие слова из словосочетания в пул ненайденных хороших слов 
            words = phrase.split(' ')
            for word in words:
                nf_good_words.add(word)
                
    
    # поиск значения метрики плохих слов
    for word in bad_words:
        if word in question:
            bad_words_hits.add(word)
            bw_metric += metric_value(word) # можно сделать просто инкремент
        else:
            nf_bad_words.add(word)
            
    # метрика ненайденных плохих слов
    nfb_metric += sum([metric_value(word) for word in nf_bad_words])
            
    # поиск значения метрики хороших слов
    for word in good_words:
        if word in question:
            good_words_hits.add(word)
            gw_metric += metric_value(word) # можно сделать просто инкремент
        else:
            nf_good_words.add(word)
    
    # поиск метрики синонимов
    for word in nf_good_words:
        _, w2v_word = map_word2vec_word(word)
        
        similiarities = model.similar_by_word(w2v_word)
        for similiarity in similiarities:
            syn_word, prob = similiarity
            if prob < syn_coeff:
                break
            
            metric = metric_value(syn_word)
            if syn_word in question:
                syn_metric += metric
            else:
                nfg_metric += metric
            
    metrics = [bp_metric, gp_metric, bw_metric, gw_metric, syn_metric, nfb_metric, nfg_metric]
    hits = (bad_phrases_hits, good_phrases_hits, bad_words_hits, good_words_hits)
    
    return (metrics, hits)


def print_metric(metrics, hits=None):
    titles = [
        'плохие словосочетания', 'хорошие словосочетания',
        'плохие слова', 'хорошие слова',
        'метрика по синонимам',
        'ненайденные плохие слова/сочетания', 'ненайденные хорошие слова/сочетания'
    ]
    for i in range(len(metrics)):
        print(titles[i], ':', metrics[i])

    if hits is not None:
        bp_hits, gp_hits, bw_hits, gw_hits = hits
        print('---')
        print('плохие словосочетания', ':', bp_hits)
        print('хорошие словосочетания', ':', bp_hits)
        print('плохие слова', ':', bp_hits)
        print('хорошие слова', ':', bp_hits)

# %%
# вопрос, который задал юзер сейчас
actual_question = 'Здравствуйте, можно ли изменить цену в оферте, которой уже присвоен номер? Или нужно создавать новую оферту?'
print('actual question:', actual_question)

# проходимся по всей базе вопросов
for question in questions:
    metric, hits = find_metric(actual_question, question)
    
    # смотрим на метрики, если сумма положительных метрик больше единицы, то печатаем вопрос из базы
    if sum(metric[:4]) > 1:
        print(question)
        print_metric(metric, hits)
        print('======')
# Out:
# actual question: Здравствуйте, можно ли изменить цену в оферте, которой уже присвоен номер? Или нужно создавать новую оферту?
# как действовать, если в новой оферте указано "нет связи с сте"?
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# Добрый день. У меня Оферта Оферта №0549465-19, могу я изменить цену оферты? Если возможно, как это сделать? Кодолов Максим
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# Добрый день! Как добавить новую оферту, если в СТЕ нет совпадений?
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# Здравствуйте, у меня не редактируется моя оферта, графа: цена за единицу продукции с НДС и цена за единицу продукции без НДС, у меня горит кружочек красный с НДС, а фирма на упрощенке и мне нужно выделить кружочек без НДС, но он не активный!!! До создания оферты осталось 6 часов, как быть? вчера консультант отправила обращение в тех. поддержку, но они вряд ли успеют исправить, что нужно предпринять?
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# В оферте у поставщика цена за ед. 49,00, кол-во Заказчика 2040, сумма договора считается как 99 951,84 руб. Это не верно. При переносе в РИС Закупки сделка не пройдет.
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# Добрый день. Вопрос вот в чем. Мы заключаем договоры на заправку транспорта через АЗС. В договоре до 100 т.р. не обязательна фиксированная цена (именно такой договор приложен к оферте), главное сумма договора и сроки поставки. Согласно оферте прописана цена за литр. Т.к. поставка может быть как месяц, так и год, цена не может быть одинаковая. Оферту с одним и тем же товаром я могу сделать одну. Обязательно ли цена оферты все таки должна быть фиксированной или, как в договоре, достаточно суммы договора?
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# Добрый вечер! Не могу подписать оферту, удалил цены ос скидкой, система упорно ругается что они есть, удалил уже сто раз и успешно сохранил, они все равно не удалются Доброе утро! Проблема не решена, мне надо срочно подписать оферту, до 9-30
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# Ошибка!!! все дополнительные цены со скидкой должны быть меньше основной цены за единицу продукции. Почему????? Цена со скидкой меньше. Ошибку выдает даже если нет цен со скидкой Ошибку выдает если пытаться создать оферту копированием уже имеющейся.
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# Здравствуйте! Не могу найти где можно создать новую оферту, подскажите пожалуйста
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# ИП Сыромятников Александр Михайлович ИНН 595300009501 с. Уинское, Пермский край зарегистрировался на сайте закупки.мос.ру как поставщик. Скажите пожалуйста как мне разместить информацию о товаре, количестве и цене. Я попробовал зайти в закладку Оферты, но сайт зависает, 15 минут крутится, пробовали заходить несколько раз но та же ситуация. Тел 8-902-633-37-29
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# Здравствуйте, до создания оферты осталось 18 часов, не могу ее отредактировать, изначально был выделен кружочек: цена за единицу с НДС, но мы на упрощенке и нам нужно выделить кружочек: цена за единицу без НДС, а он не реагирует. Кэш чистил, не помогает, что делать??????? ХЭЛП!!!!!
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# Я создаю новую оферту. Написано: Ввод сведений. Это значит, что вы вводите сведения из оферты, а потом присвоите номер?
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# Добрый день! Подскажите пожалуйста, создали новую оферту, все заполнили. Пишет что номер не присвоен, статус: ввод сведений. Правильно ли я понимаю, что оферты на модерации и номер будет присвоен позже? Или необходимо сделать какие то действия вручную? Спасибо. Спасибо, справились сами.
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# Добрый день. 22.02.2018 мы сформировали и подписали оферту. Но сегодня поставщики сообщили, что не видят ее. У себя в профиле "Мои оферт ы" ее тоже нет. При попытке сформировать новую вышло сообщение. что данный товар уже есть, для формирования новой оферты предыдущую нужно перенести в архив.
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# Добрый день! Куда прикреплять договор в новой оферте на обслуживание техники?
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# Здравствуйте! Подскажите как создать оферту. Не можем найти значок создание новой оферты.
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# К одной или нескольким позиций спецификации не прикреплены оферты или цены с предложением. Откройте вкладку "Предложения" и прикрепите недостающие оферты или укажите цены
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# Добрый день!Как создать новую оферту?Так как в личном кабинете не могу найти вкладку,как она была раньше.Где её найти?
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# Здравствуйте, делаю оферту. 1 . что такое артикул оферты. 2. при выборе мест доставки, будет ли входить доставка в цену продукции, озвучиваемой в оферте. спасибо.
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======
# добрый день, подскажите, пожалуйста, как я могу создать новую оферту???
# плохие словосочетания : 2.0
# хорошие словосочетания : 0.0
# плохие слова : 0.0
# хорошие слова : 0.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 0.0
# ненайденные хорошие слова/сочетания : 2.0
# ---
# плохие словосочетания : {'новый оферта'}
# хорошие словосочетания : {'новый оферта'}
# плохие слова : {'новый оферта'}
# хорошие слова : {'новый оферта'}
# ======
# Добрый день, мне 2 раз отклоняют заявку на создание оферты из -за раздела характеристики ... Причина: *Раздел "Характеристики" заполнен некорректно. Допущена одна или несколько из перечисленных ошибок/не соблюдено одно или несколько из перечисленных требований: в одной заявке не должно быть нескольких ценовых предложений; необходимо указывать модель и артикул СТЕ; предложенных характеристик недостаточно для сопоставления СТЕ; необходимо выделить перечень значимых характеристик; каждую характеристику добавлять отдельной строкой; в списке наименований характеристик не должно быть дублирования характеристик и характеристик не свойственных СТЕ; необходимо отразить характеристики СТЕ, указанные в наименовании заявки, модели или в дополнительном текстовом описании; указать минимальный и максимальный диапазон значения характеристики; укажите характеристику "совместимость" (для совместимых товаров); в наименовании характеристики товара "Производитель" - должна быть отражена компания производитель, а в графе "Страна производитель" - страна, в которой был произведен товар; не заполнены поле/поля характеристики "Наименование"; не заполнены поле/поля "Единицы измерения"; необходимо указывать единицы измерения в поле "Единицы измерения" и их значения в поле "Значение" для измеряемых характеристик; наименование, значение и единицы измерения характеристик не должны дублироваться; не заполнены поле/поля "Значение"; некорректно заполнены поле/поля "Единицы измерения" или "Значение" у меня не было нескольких ценовых предложений , там даже строки такой нет куда бы можно было вставить еще цену... Модель и артикул я указал
# плохие словосочетания : 0.0
# хорошие словосочетания : 0.0
# плохие слова : 1.0
# хорошие слова : 1.0
# метрика по синонимам : 0.0
# ненайденные плохие слова/сочетания : 1.0
# ненайденные хорошие слова/сочетания : 0.0
# ---
# плохие словосочетания : set()
# хорошие словосочетания : set()
# плохие слова : set()
# хорошие слова : set()
# ======

# %%
# model.similar_by_word('авторизация_NOUN')
# model.similar_by_word('лот_NOUN')
# Out:
# [('аукцион_NOUN', 0.4976411759853363),
#  ('фунт_NOUN', 0.4815886914730072),
#  ('сотбис_PROPN', 0.45511239767074585),
#  ('верп_NOUN', 0.4477660059928894),
#  ('копункт_ADJ', 0.4440169036388397),
#  ('гиня_NOUN', 0.4439319372177124),
#  ('торги_NOUN', 0.4351264238357544),
#  ('аршина_NOUN', 0.4321332573890686),
#  ('якорь_ADV', 0.42819735407829285),
#  ('золотник_NOUN', 0.4145345091819763)]
